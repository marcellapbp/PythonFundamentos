# %% [markdown]
# <a href="https://colab.research.google.com/github/marcellapbp/PythonFundamentos/blob/master/Cap02/Lab01/game_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Game Ping-Pong

#Não roda no google colab tentar com Visual_UI do Fast.ai https://towardsdatascience.com/visual-ui-54ab27216c8e
#pacote interface gráfica
from tkinter import *
#pacote funções aleatórias
import random
#pacote funções tempo
import time


#variável que armazena input do usuário após exibir o texto
level = int(input("Qual nível você gostaria de jogar? 1/2/3/4/5 \n"))
#variável tamanho que se baseia no nível que usuário escolheu
length = 500/level

#está criando uma tela?
root = Tk()
#atribuindo titulo a tela
root.title("Ping Pong")
#definindo que não pode alterar o tamanho
root.resizable(0,0)
root.wm_attributes("-topmost", -1)

canvas = Canvas(root, width=800, height=600, bd=0,highlightthickness=0)
canvas.pack()

root.update()

# Variável
count = 0
lost = False

#criando classe
class Bola:
    #definindo uma função com parâmetros
    def __init__(self, canvas, Barra, color):
        self.canvas = canvas
        self.Barra = Barra
        #criando uma bola
        self.id = canvas.create_oval(0, 0, 15, 15, fill=color)
        self.canvas.move(self.id, 245, 200)

        starts_x = [-3, -2, -1, 1, 2, 3]
        random.shuffle(starts_x)

        self.x = starts_x[0]
        self.y = -3

        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()

    #definindo uma função com parâmetros
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)

        pos = self.canvas.coords(self.id)

        if pos[1] <= 0:
            self.y = 3

        if pos[3] >= self.canvas_height:
            self.y = -3

        if pos[0] <= 0:
            self.x = 3
            
        if pos[2] >= self.canvas_width:
            self.x = -3

        self.Barra_pos = self.canvas.coords(self.Barra.id)


        if pos[2] >= self.Barra_pos[0] and pos[0] <= self.Barra_pos[2]:
            if pos[3] >= self.Barra_pos[1] and pos[3] <= self.Barra_pos[3]:
                self.y = -3
                global count
                count +=1
                score()


        if pos[3] <= self.canvas_height:
            self.canvas.after(10, self.draw)
        else:
            game_over()
            global lost
            lost = True

#criando uma classe
class Barra:
    #definindo uma função com parâmetros
    def __init__(self, canvas, color):
        self.canvas = canvas
        #criando barras
        self.id = canvas.create_rectangle(0, 0, length, 10, fill=color)
        self.canvas.move(self.id, 200, 400)

        self.x = 0

        self.canvas_width = self.canvas.winfo_width()

        self.canvas.bind_all("<KeyPress-Left>", self.move_left)
        self.canvas.bind_all("<KeyPress-Right>", self.move_right)
    #definindo uma função com parâmetros
    def draw(self):
        self.canvas.move(self.id, self.x, 0)

        self.pos = self.canvas.coords(self.id)

        if self.pos[0] <= 0:
            self.x = 0
        
        if self.pos[2] >= self.canvas_width:
            self.x = 0
        
        global lost
        
        if lost == False:
            self.canvas.after(10, self.draw)
    #definindo uma função com parâmetros
    def move_left(self, event):
        if self.pos[0] >= 0:
            self.x = -3
    #definindo uma função com parâmetros
    def move_right(self, event):
        if self.pos[2] <= self.canvas_width:
            self.x = 3

#definindo uma função com parâmetros
def start_game(event):
    global lost, count
    lost = False
    count = 0
    score()
    canvas.itemconfig(game, text=" ")

    time.sleep(1)
    Barra.draw()
    Bola.draw()

#definindo uma função sem parâmetros
def score():
    canvas.itemconfig(score_now, text="Pontos: " + str(count))

#definindo uma função sem parâmetros
def game_over():
    canvas.itemconfig(game, text="Game over!")


Barra = Barra(canvas, "orange")
Bola = Bola(canvas, Barra, "purple")


score_now = canvas.create_text(430, 20, text="Pontos: " + str(count), fill = "green", font=("Arial", 16))
game = canvas.create_text(400, 300, text=" ", fill="red", font=("Arial", 40))


canvas.bind_all("<Button-1>", start_game)
#manter o jogo executando sem parar
root.mainloop()
# Out:
# Qual nível você gostaria de jogar? 1/2/3/4/5
# 1
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-c1ee66f58838> in <module>()
#      12
#      13 #está criando uma tela?
# ---> 14 root = Tk()
#      15 #atribuindo titulo a tela
#      16 root.title("Ping Pong")
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
